# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
import numpy as np
import sys
print(sys.executable)
# Out:
# /root/anaconda3/bin/python

# %%
data = pd.read_csv('./data2/ybigta_sdss_train.csv')
X = data.iloc[:,2:]
y = data['type']
print(len(data))
X.head()
# Out:
# 171965
#         id type  fiberID  psfMag_u  psfMag_g  psfMag_r  psfMag_i  psfMag_z  \
# 0   415567  QSO      106  19.20636  18.83202  18.79017  18.36788  18.32136
# 1   733874  QSO      492  18.85419  18.60349  18.48284  18.36558  18.41101
# 2  1009150  QSO      388  19.81733  18.67198  18.46566  18.33873  18.31073
# 3   803041  QSO      531  21.77330  20.19641  20.08064  20.11380  19.83673
# 4   432241  QSO      180  22.53572  20.07427  19.23110  18.94043  18.65541
#
#    fiberMag_u  fiberMag_g     ...      petroMag_u  petroMag_g  petroMag_r  \
# 0    19.33958    18.72630     ...        18.06469    17.18273    16.74307
# 1    19.17574    18.90761     ...        18.90764    18.64323    18.49622
# 2    20.17311    19.00520     ...        19.85916    18.70682    18.51968
# 3    22.16908    20.56249     ...        21.38145    20.22594    20.13081
# 4    22.82620    20.41057     ...        22.09349    20.14050    19.25699
#
#    petroMag_i  petroMag_z  modelMag_u  modelMag_g  modelMag_r  modelMag_i  \
# 0    16.39772    16.28030    17.60089    16.82960    16.46197    16.09962
# 1    18.38058    18.47802    18.84907    18.59603    18.46161    18.34665
# 2    18.37718    18.37598    19.81720    18.66244    18.45800    18.32918
# 3    20.15601    20.04247    21.76902    20.18548    20.07931    20.10771
# 4    18.98682    18.63438    22.58755    20.07051    19.21149    18.90649
#
#    modelMag_z
# 0    16.01179
# 1    18.40146
# 2    18.31313
# 3    19.85110
# 4    18.63881
#
# [5 rows x 23 columns]

# %%
from sklearn.preprocessing import RobustScaler
rb_scaler = RobustScaler()
X_for_scaling = X.iloc[:,1:]
# type과 id를 제외하고 학습
rb_scaler.fit(X_for_scaling)
# 학습후 변환
train_rbscaled = rb_scaler.transform(X_for_scaling)
train_rbscaled
# 학습후 변환한 데이터를 다시 원래 데이터로 만들기
X_rbscaled = pd.DataFrame(train_rbscaled, columns = X_for_scaling.columns)
X_rbscaled = pd.concat([X[['fiberID']], X_rbscaled], axis=1)
X_rbscaled.head()

data_scaled = pd.concat([data[['id',"type"]], X_rbscaled], axis=1)
data_scaled.head()
# Out:
#         id type  fiberID  psfMag_u  psfMag_g  psfMag_r  psfMag_i  psfMag_z  \
# 0   415567  QSO      106 -0.435893 -0.291574 -0.061425 -0.111254  0.045898
# 1   733874  QSO      492 -0.580244 -0.413752 -0.220812 -0.112515  0.093583
# 2  1009150  QSO      388 -0.185463 -0.377135 -0.229722 -0.127228  0.040244
# 3   803041  QSO      531  0.616269  0.437863  0.607836  0.845503  0.851924
# 4   432241  QSO      180  0.928778  0.372564  0.167249  0.202501  0.223579
#
#    fiberMag_u  fiberMag_g     ...      petroMag_u  petroMag_g  petroMag_r  \
# 0   -0.526436   -0.469058     ...       -0.878988   -0.808048   -0.702073
# 1   -0.599909   -0.368806     ...       -0.453638   -0.124812    0.072741
# 2   -0.152645   -0.314845     ...        0.026496   -0.095064    0.083110
# 3    0.742433    0.546231     ...        0.794639    0.615596    0.795158
# 4    1.037113    0.462229     ...        1.153932    0.575626    0.408968
#
#    petroMag_i  petroMag_z  modelMag_u  modelMag_g  modelMag_r  modelMag_i  \
# 0   -0.717412   -0.654057   -1.076404   -0.950766   -0.802411   -0.819421
# 1    0.148958    0.295791   -0.463942   -0.125875    0.075270    0.155184
# 2    0.147472    0.251690    0.011104   -0.094863    0.073686    0.147607
# 3    0.924695    0.971942    0.968832    0.616370    0.785311    0.919010
# 4    0.413842    0.363370    1.370472    0.562681    0.404408    0.398004
#
#    modelMag_z
# 0   -0.727297
# 1    0.285476
# 2    0.248041
# 3    0.899853
# 4    0.386068
#
# [5 rows x 23 columns]

# %%
from sklearn.model_selection import train_test_split
from lightgbm import LGBMClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import log_loss, make_scorer

X_train, X_test, y_train, y_test = train_test_split(X_rbscaled, y, test_size = 0.2, random_state = 42)

# %%
lgbm_model = LGBMClassifier(boosting_type='gbdt', objective='binary', num_leaves=128,
                                learning_rate=0.005, n_estimators=2000, max_depth=30,
                                bagging_fraction=0.9, feature_fraction=0.9, reg_lambda=0.2)

# %%
lgbm_model.fit(X_train, y_train)
# Out:
# LGBMClassifier(bagging_fraction=0.9, boosting_type='gbdt', class_weight=None,
#         colsample_bytree=1.0, feature_fraction=0.9,
#         importance_type='split', learning_rate=0.005, max_depth=30,
#         min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#         n_estimators=2000, n_jobs=-1, num_leaves=128, objective='binary',
#         random_state=None, reg_alpha=0.0, reg_lambda=0.2, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0)

# %%
y_prob = lgbm_model.predict_proba(X_test)
log_loss(y_true=y_test, y_pred=y_prob)
# Out:
# 0.3808803991771656

# %%
from sklearn.model_selection import train_test_split
from lightgbm import LGBMClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import log_loss, make_scorer

# 모델 기본 틀 생성
lgbm_model = LGBMClassifier(
    objective='binary', num_leaves=128, feature_fraction=0.9, reg_lambda=0.2, silent=False)

# 그리드 서치 인자 조합 생성
param_dist = { "boosting_type": ['goss'],
              "max_depth" : [15, 30, 45],
              "learning_rate" : [0.01 , 0.05, 0.1],
              "n_estimators" : [1500, 2000, 2500],
            }

# 점수를 위한 로그로스 객체 생성
# LogLoss = make_scorer(log_loss, greater_is_better=False, needs_proba=True)

# lgbm_model = LGBMClassifier(boosting_type='gbdt', objective='binary', num_leaves=10,
#                                 learning_rate=0.1, n_estimators=2000, max_depth=15,
#                                 bagging_fraction=0.9, feature_fraction=0.9, reg_lambda=0.2)

# %%
grid_search = GridSearchCV(lgbm_model, n_jobs=-1, param_grid = param_dist, cv=3, scoring="neg_log_loss")

# %%
grid_search.fit(X_rbscaled, y)
grid_search.best_estimator_
grid_search.best_score_

# %%
grid_search.best_estimator_
grid_search.best_score_
